# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*
import numpy as np
import csv
import time

model=YOLO('yolov8s.pt')

class_list = [
    "person", "bicycle", "car", "motorcycle", "airplane", "bus", "train", "truck", "boat",
    "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
    "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack",
    "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball",
    "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket",
    "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
    "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake",
    "chair", "couch", "potted plant", "bed", "dining table", "toilet", "TV", "laptop",
    "mouse", "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink",
    "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"
]

tracker=Tracker()
cap=cv2.VideoCapture('IMG_8979.MOV')
down={}
up={}

counter_down=[]
counter_up=[]

# ✅ CSV File Setup
csv_filename = "vehicles.csv"
# ✅ Create CSV file with headers if not exists
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Vehicle ID", "Vehicle Type", "Timestamp", "Red Line Y", "Blue Line Y"])

# ✅ Store vehicle IDs that crossed the red line first
crossed_red = {}

# ✅ Store vehicle IDs that completed crossing both lines
counter_down = []

# ✅ Define red and blue lines

red_line_y = 335
blue_line_y = 355
offset = 7  # Allow slight variation due to tracking jitter

# ✅ Define vehicle classes to track
vehicle_classes = ["car", "bus", "truck", "motorcycle"]  
vehicle_counts = {"car": 0, "bus": 0, "truck": 0, "motorcycle": 0}  # ✅ Count of each type

while True:    
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (1020, 500))

    # YOLO Detection
    results = model.predict(frame)
    a = results[0].boxes.data
    a = a.detach().cpu().numpy()
    px = pd.DataFrame(a).astype("float")

    # ✅ Store detections
    detections = []
    detected_vehicles = {}  # ✅ Store detected vehicles and their types

    for index, row in px.iterrows():
        x1, y1, x2, y2 = int(row[0]), int(row[1]), int(row[2]), int(row[3])
        d = int(row[5])
        vehicle_type = class_list[d]  # Get detected class

        if vehicle_type in vehicle_classes:
            detections.append([x1, y1, x2, y2])
            detected_vehicles[(x1, y1, x2, y2)] = vehicle_type  # Store type with coordinates

    # ✅ Ensure 'detections' is not empty
    bbox_id = tracker.update(np.array(detections)) if detections else []

    # ✅ Process ALL detected vehicles
    for bbox in bbox_id:
        x3, y3, x4, y4, vehicle_id = bbox  # Get bounding box & ID
        cx, cy = (x3 + x4) // 2, (y3 + y4) // 2  # Compute center
        
        # ✅ Get vehicle type from stored detections
        vehicle_type = detected_vehicles.get((x3, y3, x4, y4), "unknown")

        # ✅ Check if the vehicle crosses the RED line first
        if red_line_y - offset < cy < red_line_y + offset:
            crossed_red[vehicle_id] = (cy, vehicle_type)  # Store ID & Type

        # ✅ Only consider vehicles that crossed red before reaching blue
        if vehicle_id in crossed_red and blue_line_y - offset < cy < blue_line_y + offset:
            _, v_type = crossed_red[vehicle_id]  # Get stored vehicle type

            # ✅ Draw circle at the blue line for valid vehicles
            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            cv2.putText(frame, f"{v_type}-{vehicle_id}", (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

            # ✅ Add to counter only once
            if vehicle_id not in counter_down:
                counter_down.append(vehicle_id)
                vehicle_counts[v_type] += 1  # ✅ Increment count of detected type

                # ✅ Save data to CSV
                with open(csv_filename, mode="a", newline="") as file:
                    writer = csv.writer(file)
                    writer.writerow([vehicle_id, v_type, time.strftime("%Y-%m-%d %H:%M:%S"), crossed_red[vehicle_id][0], cy])

    # ✅ Draw reference lines
    cv2.line(frame, (260, 335), (724, 335), (0, 0, 255), 3)  # Red line
    cv2.putText(frame, 'red line', (260, 278), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

    cv2.line(frame, (200, 355), (779, 355), (255, 0, 0), 3)  # Blue line
    cv2.putText(frame, 'blue line', (200, 315), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

    # ✅ Display vehicle count
    cv2.putText(frame, f"Cars: {vehicle_counts['car']}  Buses: {vehicle_counts['bus']}  Trucks: {vehicle_counts['truck']}  Motorcycles: {vehicle_counts['motorcycle']}", 
                (60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)    

    cv2.imshow("frames", frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 4 cars, 1 motorcycle, 1 bus, 2 trucks, 409.8ms
# Speed: 7.7ms preprocess, 409.8ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 motorcycle, 1 truck, 281.9ms
# Speed: 5.5ms preprocess, 281.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 motorcycle, 1 truck, 302.8ms
# Speed: 5.8ms preprocess, 302.8ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 truck, 248.6ms
# Speed: 2.9ms preprocess, 248.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 truck, 262.6ms
# Speed: 4.1ms preprocess, 262.6ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 truck, 309.9ms
# Speed: 5.9ms preprocess, 309.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 truck, 248.6ms
# Speed: 4.5ms preprocess, 248.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 truck, 245.4ms
# Speed: 6.0ms preprocess, 245.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 1 truck, 279.3ms
# Speed: 4.2ms preprocess, 279.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 1 truck, 381.6ms
# Speed: 4.5ms preprocess, 381.6ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 1 truck, 296.3ms
# Speed: 6.8ms preprocess, 296.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 motorcycle, 2 trucks, 308.5ms
# Speed: 5.3ms preprocess, 308.5ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 1 truck, 366.2ms
# Speed: 6.9ms preprocess, 366.2ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 bus, 1 truck, 406.0ms
# Speed: 15.4ms preprocess, 406.0ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 1 bus, 389.7ms
# Speed: 14.0ms preprocess, 389.7ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 bus, 373.7ms
# Speed: 8.6ms preprocess, 373.7ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 342.9ms
# Speed: 9.8ms preprocess, 342.9ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 1 truck, 457.2ms
# Speed: 9.6ms preprocess, 457.2ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 motorcycle, 1 truck, 454.8ms
# Speed: 7.0ms preprocess, 454.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 433.9ms
# Speed: 15.9ms preprocess, 433.9ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 402.1ms
# Speed: 11.2ms preprocess, 402.1ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 565.1ms
# Speed: 24.8ms preprocess, 565.1ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 482.9ms
# Speed: 7.5ms preprocess, 482.9ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 611.1ms
# Speed: 8.8ms preprocess, 611.1ms inference, 9.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 384.2ms
# Speed: 7.9ms preprocess, 384.2ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 trucks, 363.2ms
# Speed: 5.8ms preprocess, 363.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 trucks, 334.6ms
# Speed: 5.5ms preprocess, 334.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 352.3ms
# Speed: 5.6ms preprocess, 352.3ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 336.1ms
# Speed: 5.4ms preprocess, 336.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 trucks, 329.6ms
# Speed: 6.6ms preprocess, 329.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 trucks, 324.8ms
# Speed: 5.2ms preprocess, 324.8ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 trucks, 322.7ms
# Speed: 6.1ms preprocess, 322.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 328.1ms
# Speed: 5.5ms preprocess, 328.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 trucks, 338.6ms
# Speed: 6.0ms preprocess, 338.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 358.2ms
# Speed: 5.3ms preprocess, 358.2ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 336.2ms
# Speed: 5.5ms preprocess, 336.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 366.9ms
# Speed: 7.5ms preprocess, 366.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 346.4ms
# Speed: 4.9ms preprocess, 346.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 2 trucks, 340.6ms
# Speed: 5.9ms preprocess, 340.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
